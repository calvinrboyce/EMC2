# %% [markdown]
# Hello World

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)

# %%
import matplotlib.pyplot as plt
a=[1/factorial(k) for k in range(1000)]
b=[1]
for i in range(1,len(a)):
    b.append(b[i-1]+a[i])
    
print(b)
plt.plot(b)
plt.show()
# Out:
# [1, 2.0, 2.5, 2.6666666666666665, 2.708333333333333, 2.7166666666666663, 2.7180555555555554, 2.7182539682539684, 2.71827876984127, 2.7182815255731922, 2.7182818011463845, 2.718281826198493, 2.7182818282861687, 2.7182818284467594, 2.71828182845823, 2.718281828458995, 2.718281828459043, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284590455, 2.7182818284
# ...
